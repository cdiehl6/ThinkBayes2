# %%
import thinkbayes2
import thinkplot

# %%
pmfX=thinkbayes2.NormalPdf(163,7.3).MakePmf()
pmfY=thinkbayes2.NormalPdf(178,7.7).MakePmf()
thinkplot.Pmf(pmfX)
thinkplot.Pmf(pmfY)

# %%
n=1000
xs=pmfX.MakeCdf().Sample(n)
ys=pmfY.MakeCdf().Sample(n)
zs=xs+ys
pmfz=thinkbayes2.Pmf(zs)
thinkplot.Pmf(pmfz)

# %%
pmfZ=pmfX+pmfY
thinkplot.Pmf(pmfz)

# %%
def PmfProduct(pmf1,pmf2):
    pmf=thinkbayes2.pmf()
    for v1, p1 in pmf1.Items():
        for v2, p2 in pmf2.Items():
            pmf.Incr(v1*v2,p1*p2)
    return pmf

# %%
pmfZ=PmfProduct(pmfX,pmfY)
thinkplot.Cdfs(pmfz.MakeCdf())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ec6c0465856c> in <module>()
# ----> 1 pmfZ=PmfProduct(pmfX,pmfY)
#       2 thinkplot.Cdfs(pmfz.MakeCdf())
#
# <ipython-input-30-c0b836a5a9e4> in PmfProduct(pmf1, pmf2)
#       1 def PmfProduct(pmf1,pmf2):
# ----> 2     pmf=thinkbayes2.pmf()
#       3     for v1, p1 in pmf1.Items():
#       4         for v2, p2 in pmf2.Items():
#       5             pmf.Incr(v1*v2,p1*p2)
#
# AttributeError: 'module' object has no attribute 'pmf'

# %%
pmfZ=pmfX+pmfY

# %%
def PmfProbSumGreater(pmf1,pmf2,pmf3):
    pmf4=pmf1+pmf2
    p=pmf4.ProbGreater(pmf3)
    return p

PmfProbSumGreater(pmfX,pmfY,pmfZ)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8a0d4d478f42> in <module>()
#       4     return p
#       5
# ----> 6 PmfProbSumGreater(pmfX,pmfY,pmfZ)
#
# <ipython-input-36-8a0d4d478f42> in PmfProbSumGreater(pmf1, pmf2, pmf3)
#       1 def PmfProbSumGreater(pmf1,pmf2,pmf3):
#       2     pmf4=pmf1+pmf2
# ----> 3     p=pmf4.ProbGreater(pmf3)
#       4     return p
#       5
#
# /home/rocketraccoon/ThinkBayes2/code/thinkbayes2.pyc in ProbGreater(self, x)
#     448         returns: float probability
#     449         """
# --> 450         t = [prob for (val, prob) in self.d.items() if val > x]
#     451         return sum(t)
#     452
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
