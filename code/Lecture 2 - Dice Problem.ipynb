# %%
import thinkbayes2
import thinkplot
from dice import Dice

# %%
d = {4:2,6:6,8:3,10:2,12:4,20:4}
pmf=Dice(d)

# %%
thinkplot.Hist(pmf)

# %%
pmf.Update(6)
# Out:
# 0.10039682539682537

# %%
thinkplot.Hist(pmf)

# %%
cdf=pmf.MakeCdf()
thinkplot.Cdf(cdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
pmf.Update(6)
thinkplot.Hist(pmf)

# %%
pmf.Update(5)
thinkplot.Hist(pmf)

# %%
pmf.Update(8)
thinkplot.Hist(pmf)
