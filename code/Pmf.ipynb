# %%
import thinkbayes2
import thinkplot

# %%
d6 = thinkbayes2.Pmf(range(1,7))

# %%
thinkplot.Hist(d6)

# %%
thinkplot.Pmf(d6)

# %%
thinkplot.Pdf(d6)

# %%
twoDice = d6 + d6

# %%
thinkplot.Hist(twoDice)

# %%
threeDice = d6 + d6 + d6
thinkplot.Pdf(threeDice)

# %%
fourDice = d6 + d6 + d6 + d6
thinkplot.Pdf(fourDice)

# %%
fiveDice = d6 + d6 + d6 + d6 +d6
thinkplot.Pdf(fiveDice)

# %%
thinkplot.Pdfs([d6,twoDice,threeDice,fourDice,fiveDice])

# %%
print threeDice.Mean()
print threeDice.Var()
print thinkbayes2.Std(threeDice)
# Out:
# 10.5
# 8.75
# 0.0467820294302

# %%
threeDice.ProbGreater(15)
# Out:
# 0.046296296296296294

# %%
threeDice.Random()
# Out:
# 8

# %%
# Out:
# Strength 13
# Intelligence 9
# Wisdom 9
# Dexterity 14
# Constitution 10
# Charisma 11
